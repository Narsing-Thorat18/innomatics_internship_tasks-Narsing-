# %% [markdown]
# <a href="https://colab.research.google.com/github/Narsing-Thorat18/innomatics_internship_tasks-Narsing-/blob/main/Copy_of_16_feb_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem Statement 1: Employee Performance Bonus Eligibility**

# %%
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}
highest_score = max(employees.values())
top_performers = [name for name, score in employees.items() if score == highest_score]
print(f"Top Performers Eligible for Bonus: {', '.join(top_performers)} (Score: {highest_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# **Problem Statement 2: Search Query Keyword Analysis**

# %%
import string
#Input sentence
query = "Buy mobile phone buy phone online"

#Convert to lowercase
query = query.lower()

#Remove punctuation
query = query.translate(str.maketrans('', '', string.punctuation))

#Split sentence into words
words = query.split()

#Count frequency of each word
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1
#Display words that appear more than once
result = {word: count for word, count in word_count.items() if count > 1}
print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# **Problem Statement 3: Sensor Data Validation**

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
valid_readings = []
for hour, value in enumerate(sensor_readings):
    if value % 2 == 0:   # Check if the reading is even
        valid_readings.append((hour, value))
print("Valid Sensor Readings (Hour, Value):")
print(valid_readings)
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# **Problem Statement 4: Email Domain Usage Analysis**

# %%
#Email Analysis

emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]
# Dictionary to store domain counts
domain_count = {}
for email in emails:
    domain = email.split("@")[1]

    if domain in domain_count:
        domain_count[domain] += 1
    else:
        domain_count[domain] = 1


total_emails = len(emails)

for domain, count in domain_count.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {int(percentage)}%")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# **Problem Statement 5: Sales Spike Detection**

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

average_sales = sum(sales) / len(sales)
threshold = average_sales * 1.30
for day, value in enumerate(sales, start=1):
    if value > threshold:
        print(f"Day {day}: {value}")
# Out:
# Day 6: 3000

# %% [markdown]
# **Problem Statement 6: Duplicate User ID Detection**

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
id_count = {}
for user in user_ids:
    if user in id_count:
        id_count[user] += 1
    else:
        id_count[user] = 1

for user, count in id_count.items():
    if count > 1:
        print(f"{user} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times
